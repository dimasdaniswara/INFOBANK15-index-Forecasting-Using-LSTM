# %%
import yfinance as yf
import pandas as pd
import pandas_datareader as web
import matplotlib.pyplot as plt
import numpy as np

# %%
pip install pandas_datareader
# Out:
# Requirement already satisfied: pandas_datareader in c:\users\dimas\anaconda3\lib\site-packages (0.10.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: requests>=2.19.0 in c:\users\dimas\anaconda3\lib\site-packages (from pandas_datareader) (2.27.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\dimas\anaconda3\lib\site-packages (from pandas_datareader) (1.1.0)
# Requirement already satisfied: lxml in c:\users\dimas\anaconda3\lib\site-packages (from pandas_datareader) (4.5.2)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in c:\users\dimas\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\users\dimas\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dimas\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2020.6.20)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dimas\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (1.25.9)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\dimas\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (1.19.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\dimas\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\dimas\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (2020.1)
# Requirement already satisfied: six>=1.5 in c:\users\dimas\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas_datareader) (1.15.0)

# %%
import yfinance as yf

# %%
assa = yf.Ticker("ASSA.JK")

# %%
assa.info['trailingEps']
# Out:
# 36.6

# %%
assa.history(period="5y")
# Out:
#                    Open         High          Low        Close    Volume  \
# Date
# 2017-05-26   235.960343   235.960343   228.469538   230.342239    194500
# 2017-05-29   226.596827   234.087631   226.596827   234.087631    127700
# 2017-05-30   237.833023   237.833023   232.214920   232.214920    247900
# 2017-05-31   232.214930   235.960332   232.214930   234.087631     83900
# 2017-06-01   234.087631   234.087631   234.087631   234.087631         0
# ...                 ...          ...          ...          ...       ...
# 2022-05-19  1980.000000  2200.000000  1860.000000  2130.000000  30319900
# 2022-05-20  2150.000000  2170.000000  2090.000000  2140.000000  10733300
# 2022-05-23  2140.000000  2160.000000  2070.000000  2070.000000   4956600
# 2022-05-24  2070.000000  2140.000000  2070.000000  2110.000000   5967900
# 2022-05-25  2110.000000  2120.000000  2020.000000  2060.000000   7384000
#
#             Dividends  Stock Splits
# Date
# 2017-05-26        0.0             0
# 2017-05-29        0.0             0
# 2017-05-30        0.0             0
# 2017-05-31        0.0             0
# 2017-06-01        0.0             0
# ...               ...           ...
# 2022-05-19        0.0             0
# 2022-05-20        0.0             0
# 2022-05-23        0.0             0
# 2022-05-24        0.0             0
# 2022-05-25        0.0             0
#
# [1255 rows x 7 columns]

# %%
stocks = ['ATIC.JK','MLPT.JK','EMTK.JK','MTDL.JK','PTSN.JK',
         'MDKA.JK','ANTM.JK','INCO.JK','TINS.JK','ESSA.JK',
         'MNCN.JK','LPPF.JK','SCMA.JK','ERAA.JK','ACES.JK',
         'ADRO.JK','HRUM.JK','PTBA.JK','ITMG.JK','PGAS.JK',
         'SMDR.JK','ASSA.JK','GIAA.JK','BIRD.JK','IATA.JK',
         'KLBF.JK','MIKA.JK','SIDO.JK','KAEF.JK','SAME.JK',
         'UNVR.JK','AMRT.JK','GZCO.JK','ICBP.JK','JPFA.JK',
         'ASII.JK','MARK.JK','MLPL.JK','ARNA.JK','ABMM.JK',
         'BBCA.JK','BBRI.JK','BBTN.JK','BMRI.JK','BBYB.JK',
         'CTRA.JK','PWON.JK','BSDE.JK','SMRA.JK','KIJA.JK',
         'TLKM.JK','WIKA.JK','WSKT.JK','ADHI.JK','JSMR.JK']

# %%
df  = pd.DataFrame(stocks , columns=['Ticker'])
df
# Out:
#      Ticker
# 0   ATIC.JK
# 1   MLPT.JK
# 2   EMTK.JK
# 3   MTDL.JK
# 4   PTSN.JK
# 5   MDKA.JK
# 6   ANTM.JK
# 7   INCO.JK
# 8   TINS.JK
# 9   ESSA.JK
# 10  MNCN.JK
# 11  LPPF.JK
# 12  SCMA.JK
# 13  ERAA.JK
# 14  ACES.JK
# 15  ADRO.JK
# 16  HRUM.JK
# 17  PTBA.JK
# 18  ITMG.JK
# 19  PGAS.JK
# 20  SMDR.JK
# 21  ASSA.JK
# 22  GIAA.JK
# 23  BIRD.JK
# 24  IATA.JK
# 25  KLBF.JK
# 26  MIKA.JK
# 27  SIDO.JK
# 28  KAEF.JK
# 29  SAME.JK
# 30  UNVR.JK
# 31  AMRT.JK
# 32  GZCO.JK
# 33  ICBP.JK
# 34  JPFA.JK
# 35  ASII.JK
# 36  MARK.JK
# 37  MLPL.JK
# 38  ARNA.JK
# 39  ABMM.JK
# 40  BBCA.JK
# 41  BBRI.JK
# 42  BBTN.JK
# 43  BMRI.JK
# 44  BBYB.JK
# 45  CTRA.JK
# 46  PWON.JK
# 47  BSDE.JK
# 48  SMRA.JK
# 49  KIJA.JK
# 50  TLKM.JK
# 51  WIKA.JK
# 52  WSKT.JK
# 53  ADHI.JK
# 54  JSMR.JK

# %%
multpl_stocks = web.get_data_yahoo(stocks,
start = "2016-05-21",
end = "2021-05-21")

# %%
multpl_stock_yearly_returns = multpl_stocks['Adj Close'].resample('Y').ffill().pct_change().mean()

# %%
yearly_returns = pd.Series(multpl_stock_yearly_returns,name = "Returns")

# %%
yearly_returns.reset_index(drop= True,inplace=True)

# %%
df.drop(['Returns'],axis = 1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-4f55087c449b> in <module>
# ----> 1 df.drop(['Returns'],axis = 1,inplace = True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4162             level=level,
#    4163             inplace=inplace,
# -> 4164             errors=errors,
#    4165         )
#    4166
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3876         for axis, labels in axes.items():
#    3877             if labels is not None:
# -> 3878                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3879
#    3880         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3910                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3911             else:
# -> 3912                 new_axis = axis.drop(labels, errors=errors)
#    3913             result = self.reindex(**{axis_name: new_axis})
#    3914
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5274         if mask.any():
#    5275             if errors != "ignore":
# -> 5276                 raise KeyError(f"{labels[mask]} not found in axis")
#    5277             indexer = indexer[~mask]
#    5278         return self.delete(indexer)
#
# KeyError: "['Returns'] not found in axis"

# %%
saham = df.join(yearly_returns)

# %%
saham
# Out:
#      Ticker   Returns
# 0   ATIC.JK  0.024077
# 1   MLPT.JK  0.326394
# 2   EMTK.JK  0.324887
# 3   MTDL.JK  0.310037
# 4   PTSN.JK  2.176304
# 5   MDKA.JK  0.519057
# 6   ANTM.JK  0.313655
# 7   INCO.JK  0.118954
# 8   TINS.JK  0.139255
# 9   ESSA.JK  0.267199
# 10  MNCN.JK  0.044680
# 11  LPPF.JK -0.245185
# 12  SCMA.JK -0.054763
# 13  ERAA.JK  0.550088
# 14  ACES.JK  0.148142
# 15  ADRO.JK  0.005829
# 16  HRUM.JK  0.327250
# 17  PTBA.JK  0.123626
# 18  ITMG.JK  0.080338
# 19  PGAS.JK -0.107986
# 20  SMDR.JK  0.253996
# 21  ASSA.JK  0.801954
# 22  GIAA.JK  0.029069
# 23  BIRD.JK -0.125102
# 24  IATA.JK  0.000000
# 25  KLBF.JK  0.011822
# 26  MIKA.JK  0.056510
# 27  SIDO.JK  0.332064
# 28  KAEF.JK  0.281794
# 29  SAME.JK  0.141711
# 30  UNVR.JK -0.019481
# 31  AMRT.JK  0.114068
# 32  GZCO.JK -0.073376
# 33  ICBP.JK  0.023074
# 34  JPFA.JK  0.148162
# 35  ASII.JK -0.067355
# 36  MARK.JK  0.354039
# 37  MLPL.JK  0.728306
# 38  ARNA.JK  0.159131
# 39  ABMM.JK -0.129154
# 40  BBCA.JK  0.262223
# 41  BBRI.JK  0.166479
# 42  BBTN.JK  0.077769
# 43  BMRI.JK  0.055357
# 44  BBYB.JK  0.029167
# 45  CTRA.JK -0.032867
# 46  PWON.JK -0.009935
# 47  BSDE.JK -0.078372
# 48  SMRA.JK -0.056021
# 49  KIJA.JK -0.069692
# 50  TLKM.JK -0.012888
# 51  WIKA.JK -0.072901
# 52  WSKT.JK -0.157555
# 53  ADHI.JK -0.099572
# 54  JSMR.JK  0.027503

# %%
data = yf.download(stocks, start="2016-05-21", end="2021-05-21")
# Out:
# [*********************100%***********************]  55 of 55 completed

# %%
tickers = yf.Tickers(stocks)

# %%
peg = []

for stock in stocks :
    value = tickers.tickers[stock].info['pegRatio']
    peg.append(value)

# %%
PEG = pd.Series(peg,name = "PEG")

# %%
saham =saham.join(PEG)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-ebaf359a5e48> in <module>
# ----> 1 saham =saham.join(PEG)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7862         """
#    7863         return self._join_compat(
# -> 7864             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7865         )
#    7866
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7885                 right_index=True,
#    7886                 suffixes=(lsuffix, rsuffix),
# -> 7887                 sort=sort,
#    7888             )
#    7889         else:
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      87         validate=validate,
#      88     )
# ---> 89     return op.get_result()
#      90
#      91
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     669
#     670         llabels, rlabels = _items_overlap_with_suffix(
# --> 671             self.left._info_axis, self.right._info_axis, self.suffixes
#     672         )
#     673
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _items_overlap_with_suffix(left, right, suffixes)
#    2089
#    2090     if not lsuffix and not rsuffix:
# -> 2091         raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2092
#    2093     def renamer(x, suffix):
#
# ValueError: columns overlap but no suffix specified: Index(['PEG'], dtype='object')

# %%
marketcap = []
for stock in stocks :
    value = tickers.tickers[stock].info['marketCap']
    marketcap.append(value)

# %%
MarketCap = pd.Series(marketcap,name="MarketCap")

# %%
saham = saham.join(MarketCap)

# %%
saham
# Out:
#      Ticker   Returns       PEG        MarketCap
# 0   ATIC.JK  0.024077       NaN     944666902528
# 1   MLPT.JK  0.326394       NaN    5662500192256
# 2   EMTK.JK  0.324887       NaN  111185026351104
# 3   MTDL.JK  0.310037       NaN    8655214215168
# 4   PTSN.JK  2.176304       NaN    1105382735872
# 5   MDKA.JK  0.519057       NaN  122965584773120
# 6   ANTM.JK  0.313655       NaN  353973420687360
# 7   INCO.JK  0.118954      0.00   79242314383360
# 8   TINS.JK  0.139255     -1.73   12959085494272
# 9   ESSA.JK  0.267199       NaN   19889343430656
# 10  MNCN.JK  0.044680       NaN   12367432777728
# 11  LPPF.JK -0.245185       NaN   14640785391616
# 12  SCMA.JK -0.054763      1.26   14303494144000
# 13  ERAA.JK  0.550088       NaN    8028742483968
# 14  ACES.JK  0.148142      1.50   17291604393984
# 15  ADRO.JK  0.005829      0.00  105873661755392
# 16  HRUM.JK  0.327250      0.00   27915282546688
# 17  PTBA.JK  0.123626      0.41   46523161247744
# 18  ITMG.JK  0.080338      0.00   36241307336704
# 19  PGAS.JK -0.107986      0.00   38180363436032
# 20  SMDR.JK  0.253996       NaN    8842823860224
# 21  ASSA.JK  0.801954       NaN    7622102089728
# 22  GIAA.JK  0.029069       NaN    5746825101312
# 23  BIRD.JK -0.125102      1.84    2990141079552
# 24  IATA.JK  0.000000       NaN    2328823070720
# 25  KLBF.JK  0.011822      2.39   76168459976704
# 26  MIKA.JK  0.056510      7.93   39666199822336
# 27  SIDO.JK  0.332064      1.31   28579391864832
# 28  KAEF.JK  0.281794       NaN    8275459833856
# 29  SAME.JK  0.141711       NaN    6714803355648
# 30  UNVR.JK -0.019481     17.96  192657502502912
# 31  AMRT.JK  0.114068      2.47   73705984098304
# 32  GZCO.JK -0.073376       NaN    1379999940608
# 33  ICBP.JK  0.023074      1.40   93878296248320
# 34  JPFA.JK  0.148162       NaN   12914545131520
# 35  ASII.JK -0.067355      0.99  288445641523200
# 36  MARK.JK  0.354039       NaN    4351000051712
# 37  MLPL.JK  0.728306       NaN    2561929904128
# 38  ARNA.JK  0.159131       NaN    7562047520768
# 39  ABMM.JK -0.129154       NaN    9030397329408
# 40  BBCA.JK  0.262223      1.66  912235014651904
# 41  BBRI.JK  0.166479      0.85  664690480906240
# 42  BBTN.JK  0.077769      0.58   17579399708672
# 43  BMRI.JK  0.055357      0.38  373050423902208
# 44  BBYB.JK  0.029167       NaN   12965182963712
# 45  CTRA.JK -0.032867      1.77   18350344241152
# 46  PWON.JK -0.009935      1.02   24079801253888
# 47  BSDE.JK -0.078372      0.84   19240327315456
# 48  SMRA.JK -0.056021      0.67   11556020551680
# 49  KIJA.JK -0.069692       NaN    3428910891008
# 50  TLKM.JK -0.012888  33640.20  413089384103936
# 51  WIKA.JK -0.072901      1.46    8116809760768
# 52  WSKT.JK -0.157555      0.78    6624112017408
# 53  ADHI.JK -0.099572       NaN    2385769398272
# 54  JSMR.JK  0.027503     -5.92   26636382633984

# %%
earnings = []
for stock in stocks :
    value = tickers.tickers[stock].info['earningsGrowth']
    earnings.append(value)

# %%
#from sahamee
PEGnew = [0.02,1.84,0.79,0.94,7596.23,
          -3.54,1.29,1.28,0.4,4.03,
          0.45 ,-1.13,-4.63,0.32,-136.11,
          0.32 , 1.04 , 0.25 , 0.21 , -301.18,
          0.31, 2.85, 0, -6.95, -12.61,
          3.57, 2.86, 1.06, 10.63, 1.98,
          -15.26, 1.49, 3.68, 1.23, -15.32,
          2.41 , 0.44, -3.63, 0.63, 0.16,
          3.27, 6.2, -3.88, 0.86, 0.19,
          0.93, -4.65, -2.55, 45.46, -26.24,
          3.32, -1.98, -1.57, -1.51, -5.53]

# %%
saham.drop('PEG',axis=1,inplace = True)

# %%
PEG = pd.Series(PEGnew,name = "PEG")

# %%
saham = saham.join(PEG)

# %% [markdown]
# # K-MEANS

# %%
saham.set_index('Ticker',inplace = True)

# %%
from sklearn.cluster import KMeans
import pylab as pl

# %%
X = saham.values
sse = []
for k in range(1,11):
    
    kmeans = KMeans(n_clusters = k,init = 'k-means++',max_iter= 300, n_init = 10, random_state = 0)
    kmeans.fit(X)
    
    sse.append(kmeans.inertia_) #SSE for each n_clusters
pl.plot(range(1,11), sse)
pl.title("Elbow Curve")
pl.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-231ea6380935> in <module>
#       1 model = KMeans(random_state=123)
#       2 # Instantiate the KElbowVisualizer with the number of clusters and the metric
# ----> 3 visualizer = KElbowVisualizer(model, k=(2,6), metric='silhouette', timings=False)
#       4 # Fit the data and visualize
#       5 visualizer.fit(X)
#
# NameError: name 'KElbowVisualizer' is not defined

# %%
kmeans = KMeans(n_clusters = 3).fit(X)
centroids = kmeans.cluster_centers_
pl.scatter(X[:,0],X[:,1], c = kmeans.labels_, cmap ="rainbow" , label = 'centroids',marker = "o")
# pl.scatter(centroids[:,0],centroids[:,1],s=250 ,marker='*')
# plt.legend(scatterpoints=1)
pl.show()

# %%
print(saham.idxmax())
# Out:
# Returns      PTSN.JK
# MarketCap    BBCA.JK
# PEG          PTSN.JK
# dtype: object

# %%
saham.drop("PTSN.JK",inplace = True)

# %%
X = saham.values
kmeans = KMeans(n_clusters = 3, init='random',n_init=10,max_iter=300)
y_km = kmeans.fit_predict(X)
centroids = kmeans.cluster_centers_
pl.scatter(X[y_km == 0,0],X[y_km ==0,1], s=50,c='lightgreen',marker ='o',edgecolor='black',label ='cluster 1')
pl.scatter(X[y_km == 1,0],X[y_km ==1,1], s=50,c='orange',marker ='o',edgecolor='black',label ='cluster 2')
pl.scatter(X[y_km == 2,0],X[y_km ==2,1], s=50,c='lightblue',marker ='o',edgecolor='black',label ='cluster 3')
pl.scatter(centroids[:,0],centroids[:,1], s=250,c='red',marker ='*',edgecolor='black',label ='centroids')
plt.legend(scatterpoints=1)
plt.grid()
plt.show()

# %%
Company = pd.DataFrame(saham.index)
cluster_labels = pd.DataFrame(kmeans.labels_)
df = pd.concat([Company,yearly_returns,PEG,MarketCap,cluster_labels],axis = 1)

# %%
df.columns = [['Ticker','Returns','PEG','MarketCap','Labels']]

# %%
df
# Out:
#      Ticker   Returns      PEG        MarketCap Labels
# 0   ATIC.JK  0.024077     0.02     944666902528      0
# 1   MLPT.JK  0.326394     1.84    5662500192256      0
# 2   EMTK.JK  0.324887     0.79  111185026351104      0
